# %%
import gensim
# Out:
# /usr/local/lib/python3.5/dist-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
model = gensim.models.LdaModel.load('ldamodel12-25 18:18:59.mdl', mmap='r')

# %%
model.print_topics(num_topics=20, num_words=10)
# Out:
# [(0,
#   '0.000*"時間" + 0.000*"喜歡" + 0.000*"朋友" + 0.000*"都不" + 0.000*"不想" + 0.000*"工作" + 0.000*"生活" + 0.000*"不好" + 0.000*"好好" + 0.000*"真很"'),
#  (1,
#   '0.001*"不出" + 0.001*"唸佛" + 0.001*"蔬菜" + 0.001*"雜糧" + 0.001*"法思維" + 0.001*"想不出" + 0.001*"晝夜常" + 0.001*"出作" + 0.001*"時唸" + 0.001*"夜常"'),
#  (2,
#   '0.000*"時間" + 0.000*"不想" + 0.000*"都不" + 0.000*"喜歡" + 0.000*"朋友" + 0.000*"開心" + 0.000*"生活" + 0.000*"好好" + 0.000*"東西" + 0.000*"真很"'),
#  (3,
#   '0.000*"時間" + 0.000*"喜歡" + 0.000*"不想" + 0.000*"都不" + 0.000*"工作" + 0.000*"朋友" + 0.000*"好好" + 0.000*"開心" + 0.000*"東西" + 0.000*"真很"'),
#  (4,
#   '0.000*"不想" + 0.000*"時間" + 0.000*"喜歡" + 0.000*"都不" + 0.000*"朋友" + 0.000*"好好" + 0.000*"不好" + 0.000*"生活" + 0.000*"東西" + 0.000*"開心"'),
#  (5,
#   '0.000*"時間" + 0.000*"不想" + 0.000*"喜歡" + 0.000*"東西" + 0.000*"開心" + 0.000*"不好" + 0.000*"生活" + 0.000*"朋友" + 0.000*"說不" + 0.000*"都不"'),
#  (6,
# ...

# %%
model.print_topics(num_topics=8, num_words=20)
# Out:
# [(0,
#   '0.000*"時間" + 0.000*"喜歡" + 0.000*"朋友" + 0.000*"都不" + 0.000*"不想" + 0.000*"工作" + 0.000*"生活" + 0.000*"不好" + 0.000*"好好" + 0.000*"真很" + 0.000*"東西" + 0.000*"還不" + 0.000*"說不" + 0.000*"開心" + 0.000*"很好" + 0.000*"晚上" + 0.000*"心情" + 0.000*"人生" + 0.000*"回家" + 0.000*"大概"'),
#  (1,
#   '0.001*"不出" + 0.001*"唸佛" + 0.001*"蔬菜" + 0.001*"雜糧" + 0.001*"法思維" + 0.001*"想不出" + 0.001*"晝夜常" + 0.001*"出作" + 0.001*"時唸" + 0.001*"夜常" + 0.001*"晝夜" + 0.001*"常念" + 0.001*"運動加" + 0.001*"夜常念" + 0.001*"穀雜" + 0.001*"樂觀晝" + 0.001*"雜糧加" + 0.001*"常念善" + 0.001*"作事好" + 0.001*"動加樂"'),
#  (2,
#   '0.000*"時間" + 0.000*"不想" + 0.000*"都不" + 0.000*"喜歡" + 0.000*"朋友" + 0.000*"開心" + 0.000*"生活" + 0.000*"好好" + 0.000*"東西" + 0.000*"真很" + 0.000*"發現" + 0.000*"不好" + 0.000*"說不" + 0.000*"心情" + 0.000*"很好" + 0.000*"努力" + 0.000*"人生" + 0.000*"都沒" + 0.000*"工作" + 0.000*"不不"'),
#  (3,
# ...
